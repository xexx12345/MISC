# %%
import pandas as pd
import numpy as np
import pickle
from pandas import ExcelWriter
import ffn
# %matplotlib inline

def save_xls(list_dfs, xls_path,sheet_names):
    writer = ExcelWriter(xls_path)
    for n, df in enumerate(list_dfs):
        df.to_excel(writer, sheet_names[n])
    writer.save()
    return

#pull in data from AlphaVantage
from alpha_vantage.timeseries import TimeSeries
ts = TimeSeries(key='NXY0VT9AHBRYGKKC',output_format='pandas')

# %%
active_stocks = pd.read_csv('active_names.csv', index_col = 0).dropna()

# %%
def historical_data(ticker, outsize = "full"):
    #outsize can be compact and full. 
    #compact returns only the latest 100 data points; full 
    #returns the full-length time series of up to 20 years of historical data. The "compact" option is 
    #recommended if you would like to reduce the data size of each API call
    alphavantage_link = 'https://www.alphavantage.co/query?function=TIME_SERIES_DAILY&symbol={0}&apikey=NXY0VT9AHBRYGKKC&datatype=csv&outputsize={1}'.format(ticker, outsize)
    df = pd.read_csv(alphavantage_link)
    df.index = pd.to_datetime(df.timestamp)
    return df

# %%
Main_DF = historical_data("SPY")
Main_DF = Main_DF[['timestamp','close']]
Main_DF.columns = ["timestamp","SPY"]

# %%
MOMO = active_stocks.index[0:5]

for ticker in MOMO:
    temp_df = historical_data(ticker)
    temp_df.index = pd.to_datetime(temp_df.timestamp) #set the index as the timestamp
    temp_df = temp_df[['close']]
    temp_df.columns = [ticker]
    Main_DF = Main_DF.join(temp_df, how = "left")

Main_DF.dropna(inplace = True)
Main_DF = Main_DF.sort_index()

# %%
Main_DF
# Out:
#              timestamp      SPY    AMD     TSLA    BAC        FB      JD
# timestamp
# 2014-05-22  2014-05-22  189.590   4.01  204.880  14.71   60.5200  20.900
# 2014-05-23  2014-05-23  190.350   4.02  207.300  14.72   61.3510  20.100
# 2014-05-27  2014-05-27  191.520   4.04  211.560  15.22   63.4800  22.970
# 2014-05-28  2014-05-28  191.380   4.00  210.240  15.14   63.5100  24.780
# 2014-05-29  2014-05-29  192.370   4.03  210.240  15.15   63.8300  25.400
# 2014-05-30  2014-05-30  192.680   4.00  207.770  15.14   63.3000  25.000
# 2014-06-02  2014-06-02  192.895   3.97  204.700  15.26   63.0800  24.600
# 2014-06-03  2014-06-03  192.800   3.94  204.940  15.21   62.8700  25.100
# 2014-06-04  2014-06-04  193.190   4.04  203.990  15.21   63.3400  24.540
# 2014-06-05  2014-06-05  194.450   4.08  206.900  15.43   63.1860  25.780
# 2014-06-06  2014-06-06  195.375   4.06  208.171  15.59   62.5000  26.580
# 2014-06-09  2014-06-09  195.580   4.07  205.310  15.84   62.8800  28.430
# 2014-06-10  2014-06-10  195.600   4.20  202.300  15.92   65.7700  28.350
# 2014-06-11  2014-06-11  194.920   4.29  204.470  15.59   65.7810  29.000
# 2014-06-12  2014-06-12  193.540   4.29  203.520  15.42   64.2901  27.170
# 2014-06-13  2014-06-13  194.130   4.28  206.420  15.44   64.5000  27.790
# 2014-06-16  2014-06-16  194.290   4.44  224.610  15.28   64.1900  26.890
# 2014-06-17  2014-06-17  194.830   4.47  231.670  15.59   64.4000  27.019
# 2014-06-18  2014-06-18  196.255   4.40  227.120  15.65   65.6000  26.520
# 2014-06-19  2014-06-19  196.480   4.36  227.790  15.55   64.3415  25.830
# 2014-06-20  2014-06-20  195.940   4.10  229.590  15.45   64.5000  25.450
